# %% [markdown]
# ### STEP 3 – DEFINE THE REAL BUSINESS PROBLEM

# %% [markdown]
# A BA does NOT say “we need more followers.”

# %% [markdown]
# **Real Problem Statement (BA-grade)**

# %% [markdown]
# “The organization lacks external reach and credibility on Instagram, resulting in low follower growth and minimal qualified leads. Current engagement is internally driven and does not translate into student enrollment or service inquiries.”

# %% [markdown]
# This statement will go into your BRD.
