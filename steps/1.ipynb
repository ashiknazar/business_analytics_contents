# %% [markdown]
# Understood. We will start completely fresh, and we will approach this as a real Business Analyst project where YOU are the BA solving the business problem.
#
# I will guide you step-by-step as if this is an actual consulting assignment.
# Before we begin, here is the problem statement that we will solve from scratch:
#
# The organization wants to increase Instagram followers/subscribers to expand business reach.
# They provide digital marketing, web development, graphic design, data science, data analytics, and machine learning services.
# The last three technical services currently have no clients and rely only on paid internships/courses for profit.
# The company wants to expand business through social media, especially Instagram.
#
# We will now approach this as a full BA assignment.

# %% [markdown]
# ___

# %% [markdown]
# ### STEP 1 – REQUIREMENTS ELICITATION (STARTING FRESH)

# %% [markdown]
# - Your first task as the BA is to clearly understand the problem.
# - Before we proceed to analysis, recommendations, or documentation, we must gather requirements.
# - I will now begin REQUIREMENTS ELICITATION exactly as you would do in a real job.
# - I will ask you stakeholder-level questions, and you will answer them as if you are the company.

# %% [markdown]
# ___

# %% [markdown]
# These answers will help us build:
# - Problem definition
# - Stakeholder analysis
# - Business objectives
# - BRD
# - Strategy
# - Roadmap

# %% [markdown]
# ___

# %% [markdown]
# ### STEP 1: QUESTIONS FOR YOU (the BA interviewing the client)

# %% [markdown]
# Please answer each question briefly and realistically; this will allow us to build the correct solution.

# %% [markdown]
# 1. What is your CURRENT Instagram follower count?
# 2. What is your target follower count for the next 3 months and 6 months?
# 3. Who is your PRIMARY target audience?
# (choose one or more)
#    - Students
#    - Working professionals
#    - Businesses looking for services
#    - Startups
#    - International clients
#    -  Local clients

# %% [markdown]
# 4. What types of content do you currently post on Instagram?
#  - Reels
#  - Carousels
#  - Intern content
#  - Service promotions
#  - Portfolio work
#  - Company culture
#  - Technical content
#  - Memes

# %% [markdown]
# 5. What content has historically performed BEST for your page?
#
# (If you don’t know, answer “don’t know.”)

# %% [markdown]
# 6. What content has performed MOST POORLY?
# 7. How often do you currently post?
#
# (Example: once a week, twice a week, rarely, daily)

# %% [markdown]
# 8. Do you currently run paid promotions or ads?

# %% [markdown]
# 9. What is your monthly budget for social media promotions?
#
# (Example: no budget, 1000 INR, 5000 INR, 20,000 INR)

# %% [markdown]
# 10. Which service do you want more clients for first?
#   -  Web development
#   -  Digital marketing
#   -  Graphic design
#   -  Data science
#   -  Data analytics
#   -  Machine learning

# %% [markdown]
# 11. Do you have case studies / portfolio content available?
# 12. Are you targeting INDIA or GLOBAL markets?

# %% [markdown]
# ____

# %% [markdown]
# Provide your answers, and after that we will move to:
# - STEP 2 – Defining the Business Problem and Goals
# - STEP 3 – Performing Stakeholder Analysis
# - STEP 4 – Creating AS-IS and TO-BE Models
# - STEP 5 – Gap Analysis
# - STEP 6 – Strategy
# - STEP 7 – Roadmap
# - STEP 8 – Documentation (BRD + FRD)

# %% [markdown]
# ___

# %% [markdown]
# ____
