# %% [markdown]
# ### STEP 2 – CONSOLIDATE FACTS (CLIENT REALITY)

# %% [markdown]
# As a BA, your first responsibility is to freeze the current reality.

# %% [markdown]
# #### 2.1 Current State Summary (AS-IS)

# %% [markdown]
# - Followers: 390
# - Content count: 89 posts
# - Posting frequency: Weekly (irregular), videos once every 2–3 weeks
# - Engagement:
#   - Likes range: 7–80
#   - Best-performing posts: Employee-related videos
#   - Reality: Engagement is from internal circle (employees, friends, family) → NOT business-relevant

# %% [markdown]
# - Content mix:
#   - Posters
#   - Carousels
#   - Service videos
#   - Few intern success stories
#   - Few employee stories
#   - Very limited technical content
#   - Few memes / fun reels
# - Ads:
#   - Ran 1–2 paid promotions
#   - Result: 2–3 leads
#   - No fixed monthly budget

# %% [markdown]
# - Business
#   - Primary target: Students
#   - Services:
#     - Actively deliverable: Digital marketing, web dev, graphic design
#     - Not yet client-ready: Data science, analytics, ML
#   - Revenue today:
#     - Students (courses/internships)
#   - Portfolio / case studies: None
#   - Market:
#      - Services: Global
#      - Students: State-level
