# %% [markdown]
# ### STEP 4 – DEFINE BUSINESS GOALS & KPIs

# %% [markdown]
# **4.1 Business Objective (Clear & Measurable)**

# %% [markdown]
# - **Primary Objective**
#   - Increase Instagram followers from 390 → 1000 in 3 months
# - **Secondary Objectives**
#   - Attract relevant students, not internal engagement
#   - Build service credibility despite lack of case studies
#   - Generate consistent inbound inquiries

# %% [markdown]
# | Category   | KPI                                  |
# | ---------- | ------------------------------------ |
# | Growth     | Followers/month                      |
# | Reach      | Avg reach per reel                   |
# | Engagement | Engagement rate (%)                  |
# | Conversion | DMs, form fills                      |
# | Quality    | % engagement from non-internal users |
