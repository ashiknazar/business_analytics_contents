# %% [markdown]
# ### STEP 6 – DEFINE THE TO-BE STATE (TARGET OPERATING MODEL)

# %% [markdown]
# #### 6.1 What the Instagram Page SHOULD Become
# In 90 days, the page should:
#   - Be reel-first
#   - Look like a learning + service authority
#   - Attract students outside the internal network
#   - Build credibility without real clients
#
# Key shift:
#
# > From “company poster page” → “knowledge & proof page”
