# %% [markdown]
# ### STEP 8 – CONTENT TYPES (WHAT EXACTLY TO POST)

# %% [markdown]
# | Bucket                  | %   |
# | ----------------------- | --- |
# | Educational / Technical | 40% |
# | Awareness / Career      | 30% |
# | Engagement / Trend      | 20% |
# | Promotion               | 10% |

# %% [markdown]
# ___

# %% [markdown]
# **Examples (NO CLIENTS REQUIRED)**
#
# Educational
# - “3 mistakes students make in digital marketing”
# - “How websites lose users in 3 seconds”
# - “What data analysts actually do daily”

# %% [markdown]
# Awareness
# - “Why certificates don’t get you jobs”
# - “What companies expect from interns”
# - “Truth about ML careers”

# %% [markdown]
# Engagement
# - POV reels
# - Myths vs reality
# - Career memes (high-quality)

# %% [markdown]
# Promotion
# - Internship announcements
# - Limited offers
# - Free webinar announcements
