# %% [markdown]
# ### STEP 9 – IMPLEMENTATION PLAN (90 DAYS)

# %% [markdown]
# **Month 1 – Foundation**
# - Stop posters (temporarily)
# - Start reels (3/week)
# - Identify 10 repeatable reel formats
# - Remove internal-only content

# %% [markdown]
# **Month 2 – Optimization**
# - Identify top 5 performing reel formats
# - Repeat winning formats
# - Improve hooks & captions
# - Soft CTA to internships

# %% [markdown]
# **Month 3 – Scale**
# - Collaboration with:
#    - Colleges
#    - Micro creators
# - Run small paid boosts on best reels
# - Push webinars / challenges
