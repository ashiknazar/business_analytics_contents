# %% [markdown]
# ### 6-Month Business Analytics Internship Syllabus
# ##### Phase 1: Foundations of Business Analytics (Weeks 1–4)
# ___
# ___
# ___

# %% [markdown]
# ##### 1. Business & Analytics Fundamentals

# %% [markdown]
# - What is Business Analytics?
# - Types
#    - Descriptive Analytics
#    - Diagnostic Analytics
#    - Predictive Analytics
#    - Prescriptive Analytics
# - Data-driven decision making lifecycle
# - KPIs, Metrics vs Dimensions
# - Business problem framing

# %% [markdown]
# ##### 2. Excel for Business Analytics

# %% [markdown]
# - Advanced Excel:
#   - Pivot Tables
#   - VLOOKUP/XLOOKUP
#   - INDEX-MATCH
#   - Conditional formulas
# - Data cleaning
# - Basic dashboard creation
# - Scenario analysis

# %% [markdown]
# ##### 3. Statistics for Business
#
# - Descriptive statistics
# - Probability basics
# - Distributions (Normal, Binomial)
# - Sampling techniques
# - Hypothesis testing
# - A/B Testing fundamentals
# - Confidence intervals
#
# Mini Project:
# Sales performance dashboard + statistical insight report.
