# %% [markdown]
# ##### Phase 2: SQL & Data Handling (Weeks 5–8)

# %% [markdown]
# **4. SQL for Analysts**
# - SELECT, WHERE, GROUP BY
# - JOINs (INNER, LEFT, RIGHT)
# - Aggregations
# - Subqueries
# - Window functions
# - CTEs
# - Query optimization basics

# %% [markdown]
# **5. Database Concepts**
# - Relational databases
# - Data warehousing basics
# - Star vs Snowflake schema
# - OLTP vs OLAP

# %% [markdown]
# **6. Data Cleaning & EDA (Python)**
# - Pandas
# - NumPy
# - Data wrangling
# - Missing value handling
# - Outlier detection
# - Exploratory Data Analysis
#
# Mini Project:
# Customer transaction dataset analysis using SQL + Python.
