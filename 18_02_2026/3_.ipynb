# %% [markdown]
# ##### Phase 3: Data Visualization & BI Tools (Weeks 9–12)

# %% [markdown]
# **7. Visualization Principles**
# - Data storytelling
# - Choosing the right chart
# - Avoiding misleading visuals
# - KPI visualization best practices

# %% [markdown]
# **8. BI Tools**
# - Power BI / Tableau
# - Data modeling
# - DAX basics (Power BI)
# - Calculated fields
# - Dashboard design
# - Publishing & sharing

# %% [markdown]
# **9. Business Reporting**
# - Executive summary writing
# - Insight presentation techniques
# - ROI impact measurement
#
# Mini Project:
# End-to-end interactive business dashboard with business recommendations.
