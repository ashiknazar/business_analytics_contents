# %% [markdown]
# ##### Phase 4: Predictive Analytics & Machine Learning for Business (Weeks 13–18)

# %% [markdown]
# **10. Predictive Modeling**
# - Regression (Linear, Logistic)
# - Classification (Decision Tree, Random Forest)
# - Model evaluation (Accuracy, Precision, Recall, F1)
# - Cross-validation
#
# **11. Customer & Marketing Analytics**
# - Customer segmentation (K-means)
# - RFM analysis
# - Churn prediction
# - CLV basics

# %% [markdown]
# **12. Time Series Analysis**
# - Trend & seasonality
# - Moving averages
# - Forecasting basics
#
# Mini Project:
# Churn prediction or sales forecasting model with business interpretation.
