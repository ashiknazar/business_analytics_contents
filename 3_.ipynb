# %% [markdown]
# “How to increase the number of subscribers/followers on the company’s Instagram account.”

# %% [markdown]
# ___

# %% [markdown]
# This will be structured exactly like a real BA engagement:
# - Client problem definition
# - Stakeholder discussions
# - Requirement gathering
# - Necessary data collection
# - Analysis work
# - Strategy recommendations
# - Reports a BA intern must produce

# %% [markdown]
# #### BUSINESS ANALYST INTERN TRAINING PROJECT

# %% [markdown]
# Use Case: Social Media Growth – Increase Instagram Subscribers for “BrandX”

# %% [markdown]
# ___

# %% [markdown]
# #### 1. Project Background (Intern Must Understand)
