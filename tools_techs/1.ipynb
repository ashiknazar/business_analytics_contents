# %% [markdown]
# ### BUSINESS ANALYST TOOLSET – APPLIED TO YOUR INSTAGRAM PROBLEM

# %% [markdown]
# ### 1. REQUIREMENTS ELICITATION TOOLS

# %% [markdown]
# **Tool: Stakeholder Interviews**

# %% [markdown]
# **Artifact produced**
# - Requirements Elicitation Notes **(Word/Google Docs)**

# %% [markdown]
# Interview-ready statement
# > “I gathered requirements through stakeholder interviews and documented current pain points, goals, and constraints.”

# %% [markdown]
# ___

# %% [markdown]
# ### 2. STAKEHOLDER ANALYSIS MATRIX (VERY IMPORTANT)

# %% [markdown]
# **Tool: Stakeholder Power–Interest Matrix**

# %% [markdown]
# **Tool Used: Excel / Google Sheets**
# | Stakeholder    | Role           | Power  | Interest |
# | -------------- | -------------- | ------ | -------- |
# | Founder        | Decision maker | High   | High     |
# | Marketing Head | Strategy       | High   | High     |
# | Content Team   | Execution      | Medium | High     |
# | Students       | End users      | Low    | High     |
